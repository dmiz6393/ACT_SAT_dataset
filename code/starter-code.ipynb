# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
file_path_act1= "../data/act_2017.csv"
file_path_act2= "../data/act_2018.csv"
file_path_sat1= "../data/sat_2017.csv"
file_path_sat2= "../data/sat_2018.csv"

df_act1= pd.read_csv(file_path_act1)
df_sat1= pd.read_csv(file_path_sat1)

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
df_act1.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
df_sat1.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
df_sat1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_act1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
df_sat1["Evidence-Based Reading and Writing"].describe()
# Out:
# count     51.000000
# mean     569.117647
# std       45.666901
# min      482.000000
# 25%      533.500000
# 50%      559.000000
# 75%      613.000000
# max      644.000000
# Name: Evidence-Based Reading and Writing, dtype: float64

# %%
df_sat1["Math"].describe()
# Out:
# count     51.000000
# mean     547.627451
# std       84.909119
# min       52.000000
# 25%      522.000000
# 50%      548.000000
# 75%      599.000000
# max      651.000000
# Name: Math, dtype: float64

# %%
df_act1["Math"].describe()
# Out:
# count    52.000000
# mean     21.173077
# std       1.963602
# min      18.000000
# 25%      19.400000
# 50%      20.900000
# 75%      23.100000
# max      25.300000
# Name: Math, dtype: float64

# %%
df_act1["Reading"].describe()
# Out:
# count    52.000000
# mean     22.001923
# std       2.048672
# min      18.100000
# 25%      20.475000
# 50%      21.700000
# 75%      24.125000
# max      26.000000
# Name: Reading, dtype: float64

# %%
df_act1["English"].describe()
# Out:
# count    52.000000
# mean     20.919231
# std       2.332132
# min      16.300000
# 25%      19.000000
# 50%      20.550000
# 75%      23.300000
# max      25.500000
# Name: English, dtype: float64

# %%
df_act1["Science"].describe()
# Out:
# count    52.000000
# mean     21.040385
# std       3.151113
# min       2.300000
# 25%      19.900000
# 50%      21.150000
# 75%      22.525000
# max      24.900000
# Name: Science, dtype: float64

# %% [markdown]
# Answer: The data gives participation rates for both the ACT and SAT in 2017 and 2018, and the average individual section scores and overall score for each state.

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
df_sat1.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
df_act1.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# Answer: In terms of missing values in the .csv file, the data looks complete. However, from the perspective of being able to "dig deeper" into how to increase participation rates for the SAT; we are missing data such as class/socioeconomic background as well as state requirements regarding the SAT.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: The maximum possible value for each subset of the SAT is 800, the minumum possible value is 200. For each ACT subject,each are scored between 1 and 36.
#
# Resources used: https://www.princetonreview.com/college-advice/guide-to-sat-subject-test-scores
# https://blog.prepscholar.com/how-is-the-act-scored

# %%
df_act1["English"].describe()
# Out:
# count    52.000000
# mean     20.919231
# std       2.332132
# min      16.300000
# 25%      19.000000
# 50%      20.550000
# 75%      23.300000
# max      25.500000
# Name: English, dtype: float64

# %%
df_act1["Reading"].describe()
# Out:
# count    52.000000
# mean     22.001923
# std       2.048672
# min      18.100000
# 25%      20.475000
# 50%      21.700000
# 75%      24.125000
# max      26.000000
# Name: Reading, dtype: float64

# %%
df_act1["Science"].describe()
# Out:
# count    52.000000
# mean     21.040385
# std       3.151113
# min       2.300000
# 25%      19.900000
# 50%      21.150000
# 75%      22.525000
# max      24.900000
# Name: Science, dtype: float64

# %%
df_act1["Math"].describe()
# Out:
# count    52.000000
# mean     21.173077
# std       1.963602
# min      18.000000
# 25%      19.400000
# 50%      20.900000
# 75%      23.100000
# max      25.300000
# Name: Math, dtype: float64

# %%
df_sat1["Math"].describe()
# Out:
# count     51.000000
# mean     547.627451
# std       84.909119
# min       52.000000
# 25%      522.000000
# 50%      548.000000
# 75%      599.000000
# max      651.000000
# Name: Math, dtype: float64

# %%
df_sat1["Evidence-Based Reading and Writing"].describe()
# Out:
# count     51.000000
# mean     569.117647
# std       45.666901
# min      482.000000
# 25%      533.500000
# 50%      559.000000
# 75%      613.000000
# max      644.000000
# Name: Evidence-Based Reading and Writing, dtype: float64

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#The minimum value for the Math section is currently 52, which isn't a possible score for any section of the SAT.
print(df_sat1[df_sat1["Math"] == df_sat1["Math"].min()])
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
df_sat1.loc[df_sat1["State"]=="Maryland",["Math"]]= (1060-536)
#we can find the value that this should have been from the total score

# %%
df_sat1.loc[df_sat1["State"]=="Maryland"]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
#The minimum value for the Science section for the ACT is currently 2.3, which isn't a possible score for any section of the ACT.
print(df_act1[df_act1["Science"] == df_act1["Science"].min()])
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %%
#Average of english, math, reading and science is the composite score 
df_act1.loc[df_act1["State"]=="Maryland",["Science"]]= 23.8

# %%
#Wyoming has an x in its composite ACT score, we should remove this 
df_act1.loc[df_act1["State"]=="Wyoming",["Composite"]]= 20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
df_sat1.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_act1.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: In both dataframes, participation is listed as an object. These should both be an integer or float. Additionally, the ACT composite score is listed as an object, which should instead be an integer.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
def convert(rate):
    new_rate= rate.replace("%","")
    float_rate=float(new_rate)
    return float_rate

# %%
df_act1["Participation"]= df_act1["Participation"].map(convert)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
def to_int(num):
    return float(num)

# %%
df_act1["Composite"]= df_act1["Composite"].map(to_int)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
df_act1.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
df_sat1.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_sat1["Participation"]=df_sat1["Participation"].map(convert)

# %%
df_sat1.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5.0                                 593   572   1165
# 1      Alaska           38.0                                 547   533   1080
# 2     Arizona           30.0                                 563   553   1116
# 3    Arkansas            3.0                                 614   594   1208
# 4  California           53.0                                 531   524   1055

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course) 
df_sat1.columns=df_sat1.columns.str.lower()
#This actually doesn't have to be done since we change the names directly with rename below

# %%
df_sat1.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
df_act1.columns=df_act1.columns.str.lower()

# %%
df_act1.columns
# Out:
# Index(['state', 'participation', 'english', 'math', 'reading', 'science',
#        'composite'],
#       dtype='object')

# %%
#Column names should not contain spaces (underscores will suffice--this allows for using the df.column_name method to access columns in addition to df['column_name']
#Column names should be unique and informative (the only feature that we actually share between dataframes is the state).
df_sat1.rename(columns={"participation": "sat_2017_participation_rates", "evidence-based reading and writing": "sat_2017_reading_and_writing_score", "math":"sat_2017_math_score","total":"sat_2017_total_score"},inplace=True)

# %%
df_act1.rename(columns={"participation": "act_2017_participation_rates", "english": "act_2017_english_score", "math":"act_2017_math_score", "reading":"act_2017_reading_score","science":"act_2017_science_score","composite":"act_2017_composite_score"},inplace=True)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# | Feature | Type   | Dataset| Description  |
# |------|------|------|------|
# |   state  | object|   SAT  | State that data comes from|
# |------|------|------|------|
# |   sat_2017_participation_rates  | float|   SAT  | The participation rate for the SAT |
# |------|------|------|------|
# |  sat_2017_reading_and_writing_score  | int|   SAT  | The average reading and writing score|
# |------|------|------|------|
# |   sat_2017_math_score  | int|   SAT  | The average math score|
# |------|------|------|------|
# |  sat_2017_total_score  | int|   SAT  |  The average total score|
# |------|------|------|------|
# |  state  | object|   ACT  |  State that data comes from|
# |------|------|------|------|
# |  act_2017_participation_rates | float|   ACT  |  The participation rate for the ACT|
# |------|------|------|------|
# |  act_2017_english_score | float|   ACT  |  The average english score|
# |------|------|------|------|
# | act_2017_math_score | float|   ACT  |  The average math score|
# |------|------|------|------|
# | act_2017_reading_score | float|   ACT  |  The average reading score|
# |------|------|------|------|
# | act_2017_science_score | float|   ACT  |  The average science score|
# |------|------|------|------|
# | act_2017_composite_score | float|   ACT  |  The average composite score|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#The national row in the ACT - we do not need this
df_act1.drop([0],inplace=True)

# %%
df_act1.reset_index(drop=True,inplace=True)
# reset the index so it reflects the data properly

# %%
df_act1.head()
# Out:
#         state  act_2017_participation_rates  act_2017_english_score  \
# 0     Alabama                         100.0                    18.9
# 1      Alaska                          65.0                    18.7
# 2     Arizona                          62.0                    18.6
# 3    Arkansas                         100.0                    18.9
# 4  California                          31.0                    22.5
#
#    act_2017_math_score  act_2017_reading_score  act_2017_science_score  \
# 0                 18.4                    19.7                    19.4
# 1                 19.8                    20.4                    19.9
# 2                 19.8                    20.1                    19.8
# 3                 19.0                    19.7                    19.5
# 4                 22.7                    23.1                    22.2
#
#    act_2017_composite_score
# 0                      19.2
# 1                      19.8
# 2                      19.7
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
combined_2017 = pd.merge(df_act1,df_sat1, how='outer', on="state")

# %%
combined_2017.head()
# Out:
#         state  act_2017_participation_rates  act_2017_english_score  \
# 0     Alabama                         100.0                    18.9
# 1      Alaska                          65.0                    18.7
# 2     Arizona                          62.0                    18.6
# 3    Arkansas                         100.0                    18.9
# 4  California                          31.0                    22.5
#
#    act_2017_math_score  act_2017_reading_score  act_2017_science_score  \
# 0                 18.4                    19.7                    19.4
# 1                 19.8                    20.4                    19.9
# 2                 19.8                    20.1                    19.8
# 3                 19.0                    19.7                    19.5
# 4                 22.7                    23.1                    22.2
#
#    act_2017_composite_score  sat_2017_participation_rates  \
# 0                      19.2                           5.0
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
combined_2017.to_csv("../data/combined_2017.csv")

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
df_act2= pd.read_csv(file_path_act2)
df_sat2= pd.read_csv(file_path_sat2)

# %%
df_act2.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
df_act2["Participation"] = df_act2["Participation"].map(convert)

# %%
df_act2["Participation"].head()
# Out:
# 0    100.0
# 1     33.0
# 2     66.0
# 3    100.0
# 4     27.0
# Name: Participation, dtype: float64

# %%
#rename to better reflect data provided so it is clear after we merge 
df_act2.rename(columns={"State":"state","Participation": "act_2018_participation_rates","Composite":"act_2018_composite_score"},inplace=True)

# %%
df_act2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# state                           52 non-null object
# act_2018_participation_rates    52 non-null float64
# act_2018_composite_score        52 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
df_act2.loc[df_act2["state"]=="District of columbia","state"]="District of Columbia"

# %%
df_sat2["Participation"]=df_sat2["Participation"].map(convert)
#change objects to floats

# %%
df_sat2["Participation"].head()
# Out:
# 0     6.0
# 1    43.0
# 2    29.0
# 3     5.0
# 4    60.0
# Name: Participation, dtype: float64

# %%
df_sat2.rename(columns={"State":"state", "Participation": "sat_2018_participation_rates", "Evidence-Based Reading and Writing": "sat_2018_reading_and_writing_score", "Math":"sat_2018_math_score","total":"sat_2018_total_score","Total":"total"},inplace=True)

# %%
df_sat2.head()
# Out:
#         state  sat_2018_participation_rates  \
# 0     Alabama                           6.0
# 1      Alaska                          43.0
# 2     Arizona                          29.0
# 3    Arkansas                           5.0
# 4  California                          60.0
#
#    sat_2018_reading_and_writing_score  sat_2018_math_score  total
# 0                                 595                  571   1166
# 1                                 562                  544   1106
# 2                                 577                  572   1149
# 3                                 592                  576   1169
# 4                                 540                  536   1076

# %%
df_sat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# state                                 51 non-null object
# sat_2018_participation_rates          51 non-null float64
# sat_2018_reading_and_writing_score    51 non-null int64
# sat_2018_math_score                   51 non-null int64
# total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
combined_2018= pd.merge(df_sat2,df_act2, on="state",how="outer")

# %%
combined_2018.head()
# Out:
#         state  sat_2018_participation_rates  \
# 0     Alabama                           6.0
# 1      Alaska                          43.0
# 2     Arizona                          29.0
# 3    Arkansas                           5.0
# 4  California                          60.0
#
#    sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 0                                 595                  571   1166
# 1                                 562                  544   1106
# 2                                 577                  572   1149
# 3                                 592                  576   1169
# 4                                 540                  536   1076
#
#    act_2018_participation_rates  act_2018_composite_score
# 0                         100.0                      19.1
# 1                          33.0                      20.8
# 2                          66.0                      19.2
# 3                         100.0                      19.4
# ...

# %%
combined_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 7 columns):
# state                                 52 non-null object
# sat_2018_participation_rates          52 non-null float64
# sat_2018_reading_and_writing_score    52 non-null int64
# sat_2018_math_score                   52 non-null int64
# total                                 52 non-null int64
# act_2018_participation_rates          52 non-null float64
# act_2018_composite_score              52 non-null float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB

# %%
final=pd.merge(combined_2018,combined_2017, on="state", how="outer")

# %%
final.head()
# Out:
#         state  sat_2018_participation_rates  \
# 0     Alabama                           6.0
# 1      Alaska                          43.0
# 2     Arizona                          29.0
# 3    Arkansas                           5.0
# 4  California                          60.0
#
#    sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 0                                 595                  571   1166
# 1                                 562                  544   1106
# 2                                 577                  572   1149
# 3                                 592                  576   1169
# 4                                 540                  536   1076
#
#    act_2018_participation_rates  act_2018_composite_score  \
# 0                         100.0                      19.1
# 1                          33.0                      20.8
# 2                          66.0                      19.2
# 3                         100.0                      19.4
# ...

# %%
# final.isnull().sum()
df1 = final[final.isna().any(axis=1)]

# %%
df1
# Out:
# Empty DataFrame
# Columns: [state, sat_2018_participation_rates, sat_2018_reading_and_writing_score, sat_2018_math_score, total, act_2018_participation_rates, act_2018_composite_score, act_2017_participation_rates, act_2017_english_score, act_2017_math_score, act_2017_reading_score, act_2017_science_score, act_2017_composite_score, sat_2017_participation_rates, sat_2017_reading_and_writing_score, sat_2017_math_score, sat_2017_total_score]
# Index: []

# %%
final
# Out:
#                    state  sat_2018_participation_rates  \
# 0                Alabama                           6.0
# 1                 Alaska                          43.0
# 2                Arizona                          29.0
# 3               Arkansas                           5.0
# 4             California                          60.0
# 5               Colorado                         100.0
# 6            Connecticut                         100.0
# 7               Delaware                         100.0
# 8   District of Columbia                          92.0
# 9                Florida                          56.0
# 10               Georgia                          70.0
# 11                Hawaii                          56.0
# 12                 Idaho                         100.0
# 13              Illinois                          99.0
# 14               Indiana                          63.0
# 15                  Iowa                           3.0
# ...

# %%
# we need to remove the additional Maine row 
final.drop([20],inplace=True)

# %%
final
# Out:
#                    state  sat_2018_participation_rates  \
# 0                Alabama                           6.0
# 1                 Alaska                          43.0
# 2                Arizona                          29.0
# 3               Arkansas                           5.0
# 4             California                          60.0
# 5               Colorado                         100.0
# 6            Connecticut                         100.0
# 7               Delaware                         100.0
# 8   District of Columbia                          92.0
# 9                Florida                          56.0
# 10               Georgia                          70.0
# 11                Hawaii                          56.0
# 12                 Idaho                         100.0
# 13              Illinois                          99.0
# 14               Indiana                          63.0
# 15                  Iowa                           3.0
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe()
# Out:
#        sat_2018_participation_rates  sat_2018_reading_and_writing_score  \
# count                     51.000000                           51.000000
# mean                      45.745098                          563.686275
# std                       37.314256                           47.502627
# min                        2.000000                          480.000000
# 25%                        4.500000                          534.500000
# 50%                       52.000000                          552.000000
# 75%                       77.500000                          610.500000
# max                      100.000000                          643.000000
#
#        sat_2018_math_score        total  act_2018_participation_rates  \
# count            51.000000    51.000000                     51.000000
# mean            556.235294  1120.019608                     61.725490
# std              47.772623    94.155083                     34.037085
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code

def standard_deviation(data): 
    mean_value=sum(data)/len(data)
    observations=[(x-mean_value)**2 for x in data]
    sum_of_obvs= sum(observations)/ len(data)
    return sum_of_obvs**.5

# s	=	sample standard deviation
# N	=	the number of observations
# x_i	=	the observed values of a sample item
# \overline {x}	=	the mean value of the observations

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd={column: standard_deviation(final.loc[:,column]) for column in final.columns if column !="state"}
#here I discovered 52 is NaN

# %%
sd
# Out:
# {'sat_2018_participation_rates': 36.946619223539415,
#  'sat_2018_reading_and_writing_score': 47.03460978357609,
#  'sat_2018_math_score': 47.30194550378352,
#  'total': 93.22742384464433,
#  'act_2018_participation_rates': 33.70173582041031,
#  'act_2018_composite_score': 2.090779082141178,
#  'act_2017_participation_rates': 31.824175751231806,
#  'act_2017_english_score': 2.3304876369363363,
#  'act_2017_math_score': 1.9624620273436781,
#  'act_2017_reading_score': 2.0469029314842646,
#  'act_2017_science_score': 1.7361170088327353,
#  'act_2017_composite_score': 2.000786081581989,
#  'sat_2017_participation_rates': 34.92907076664508,
#  'sat_2017_reading_and_writing_score': 45.21697020437866,
#  'sat_2017_math_score': 46.65713364485503,
#  'sat_2017_total_score': 91.58351056778743}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# They aren't exactly the same. Pandas uses the unbiased estimator (N-1 in the denominator), whereas Numpy by default does not. Our manually calculated standard deviations also use N as the denominator.
# #sample standard deviation vs population standard deviation

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.
#
# RAFFY: I put my comments in a markdown below

# %%
final[["act_2018_participation_rates","state"]].sort_values(by="act_2018_participation_rates", ascending=False)
# Out:
#     act_2018_participation_rates                 state
# 0                          100.0               Alabama
# 17                         100.0              Kentucky
# 50                         100.0             Wisconsin
# 45                         100.0                  Utah
# 43                         100.0             Tennessee
# 41                         100.0        South Carolina
# 37                         100.0                  Ohio
# 36                         100.0              Oklahoma
# 34                         100.0        North Carolina
# 29                         100.0                Nevada
# 28                         100.0              Nebraska
# 27                         100.0               Montana
# 25                         100.0           Mississippi
# 18                         100.0             Louisiana
# 26                         100.0              Missouri
# 51                         100.0               Wyoming
# ...

# %%
final[["act_2017_participation_rates","state"]].sort_values(by="act_2017_participation_rates", ascending=False)
# Out:
#     act_2017_participation_rates                 state
# 0                          100.0               Alabama
# 17                         100.0              Kentucky
# 50                         100.0             Wisconsin
# 45                         100.0                  Utah
# 43                         100.0             Tennessee
# 41                         100.0        South Carolina
# 36                         100.0              Oklahoma
# 34                         100.0        North Carolina
# 29                         100.0                Nevada
# 27                         100.0               Montana
# 25                         100.0           Mississippi
# 24                         100.0             Minnesota
# 18                         100.0             Louisiana
# 26                         100.0              Missouri
# 51                         100.0               Wyoming
# 5                          100.0              Colorado
# ...

# %%
final[["sat_2018_participation_rates","state"]].sort_values(by="sat_2018_participation_rates", ascending=True)
# Out:
#     sat_2018_participation_rates                 state
# 35                           2.0          North Dakota
# 51                           3.0               Wyoming
# 42                           3.0          South Dakota
# 28                           3.0              Nebraska
# 50                           3.0             Wisconsin
# 25                           3.0           Mississippi
# 15                           3.0                  Iowa
# 45                           4.0                  Utah
# 24                           4.0             Minnesota
# 18                           4.0             Louisiana
# 17                           4.0              Kentucky
# 16                           4.0                Kansas
# 26                           4.0              Missouri
# 3                            5.0              Arkansas
# 0                            6.0               Alabama
# 43                           6.0             Tennessee
# ...

# %%
final[["sat_2017_participation_rates","state"]].sort_values(by="sat_2017_participation_rates", ascending=True)
# Out:
#     sat_2017_participation_rates                 state
# 35                           2.0          North Dakota
# 25                           2.0           Mississippi
# 15                           2.0                  Iowa
# 26                           3.0              Missouri
# 45                           3.0                  Utah
# 42                           3.0          South Dakota
# 28                           3.0              Nebraska
# 50                           3.0             Wisconsin
# 24                           3.0             Minnesota
# 51                           3.0               Wyoming
# 3                            3.0              Arkansas
# 16                           4.0                Kansas
# 17                           4.0              Kentucky
# 18                           4.0             Louisiana
# 0                            5.0               Alabama
# 43                           5.0             Tennessee
# ...

# %%
final.loc[final["sat_2018_participation_rates"]>70.0,["state"]]
#The states with SAT participation rates over 70% in 2018- still a pretty high participation rate
# Out:
#                    state
# 5               Colorado
# 6            Connecticut
# 7               Delaware
# 8   District of Columbia
# 12                 Idaho
# 13              Illinois
# 19                 Maine
# 21              Maryland
# 22         Massachusetts
# 23              Michigan
# 30         New Hampshire
# 31            New Jersey
# 33              New York
# 40          Rhode Island

# %%
final.loc[final["sat_2017_participation_rates"]>70.0,["state","sat_2017_participation_rates"]]
#The states with SAT participation rates over 70% in 2017
# Out:
#                    state  sat_2017_participation_rates
# 6            Connecticut                         100.0
# 7               Delaware                         100.0
# 8   District of Columbia                         100.0
# 9                Florida                          83.0
# 12                 Idaho                          93.0
# 19                 Maine                          95.0
# 22         Massachusetts                          76.0
# 23              Michigan                         100.0
# 30         New Hampshire                          96.0
# 40          Rhode Island                          71.0

# %%
final.loc[final["act_2018_participation_rates"]>70.0,["state","act_2018_participation_rates"]]
#The states with ACT participation rates over 70% in 2018
# Out:
#              state  act_2018_participation_rates
# 0          Alabama                         100.0
# 3         Arkansas                         100.0
# 11          Hawaii                          89.0
# 16          Kansas                          71.0
# 17        Kentucky                         100.0
# 18       Louisiana                         100.0
# 24       Minnesota                          99.0
# 25     Mississippi                         100.0
# 26        Missouri                         100.0
# 27         Montana                         100.0
# 28        Nebraska                         100.0
# 29          Nevada                         100.0
# 34  North Carolina                         100.0
# 35    North Dakota                          98.0
# 36        Oklahoma                         100.0
# 37            Ohio                         100.0
# 41  South Carolina                         100.0
# 42    South Dakota                          77.0
# ...

# %%
final.loc[final["act_2017_participation_rates"]>70.0,["state","act_2017_participation_rates"]].sort_values(by="act_2017_participation_rates", ascending=False)
#The states with ACT participation rates over 70% in 2017
# Out:
#              state  act_2017_participation_rates
# 0          Alabama                         100.0
# 26        Missouri                         100.0
# 50       Wisconsin                         100.0
# 45            Utah                         100.0
# 43       Tennessee                         100.0
# 41  South Carolina                         100.0
# 36        Oklahoma                         100.0
# 34  North Carolina                         100.0
# 29          Nevada                         100.0
# 3         Arkansas                         100.0
# 27         Montana                         100.0
# 25     Mississippi                         100.0
# 24       Minnesota                         100.0
# 18       Louisiana                         100.0
# 17        Kentucky                         100.0
# 5         Colorado                         100.0
# 51         Wyoming                         100.0
# 35    North Dakota                          98.0
# ...

# %%
final.loc[final["sat_2018_participation_rates"]<30,["state","sat_2018_participation_rates"]].sort_values(by="sat_2018_participation_rates", ascending=False)
#The states with SAT participation rates under 30% in 2018
# Out:
#             state  sat_2018_participation_rates
# 2         Arizona                          29.0
# 49  West Virginia                          28.0
# 29         Nevada                          23.0
# 37           Ohio                          18.0
# 32     New Mexico                          16.0
# 27        Montana                          10.0
# 36       Oklahoma                           8.0
# 43      Tennessee                           6.0
# 0         Alabama                           6.0
# 3        Arkansas                           5.0
# 16         Kansas                           4.0
# 17       Kentucky                           4.0
# 18      Louisiana                           4.0
# 24      Minnesota                           4.0
# 26       Missouri                           4.0
# 45           Utah                           4.0
# 50      Wisconsin                           3.0
# 28       Nebraska                           3.0
# 42   South Dakota                           3.0
# ...

# %%
final.loc[final["sat_2017_participation_rates"]<30,["state","sat_2017_participation_rates"]].sort_values(by="sat_2017_participation_rates",ascending=False)
#The states with ACT participation rates under 30% in 2017
# Out:
#             state  sat_2017_participation_rates
# 29         Nevada                          26.0
# 49  West Virginia                          14.0
# 37           Ohio                          12.0
# 5        Colorado                          11.0
# 32     New Mexico                          11.0
# 27        Montana                          10.0
# 13       Illinois                           9.0
# 36       Oklahoma                           7.0
# 0         Alabama                           5.0
# 43      Tennessee                           5.0
# 16         Kansas                           4.0
# 17       Kentucky                           4.0
# 18      Louisiana                           4.0
# 50      Wisconsin                           3.0
# 45           Utah                           3.0
# 42   South Dakota                           3.0
# 28       Nebraska                           3.0
# 3        Arkansas                           3.0
# 26       Missouri                           3.0
# ...

# %%
final.loc[final["act_2018_participation_rates"]<30,["state","act_2018_participation_rates"]].sort_values(by="act_2018_participation_rates",ascending=False)
# Out:
#             state  act_2018_participation_rates
# 4      California                          27.0
# 33       New York                          27.0
# 6     Connecticut                          26.0
# 22  Massachusetts                          25.0
# 46        Vermont                          24.0
# 47       Virginia                          24.0
# 48     Washington                          24.0
# 23       Michigan                          22.0
# 39   Pennsylvania                          20.0
# 7        Delaware                          17.0
# 30  New Hampshire                          16.0
# 40   Rhode Island                          15.0
# 19          Maine                           7.0

# %%
#example of masking 
below_10= final["act_2018_participation_rates"]<10
final.loc[below_10,["state","act_2018_participation_rates"]].sort_values(by="act_2018_participation_rates", ascending=False)
# Out:
#     state  act_2018_participation_rates
# 19  Maine                           7.0

# %% [markdown]
# 1. The following states had the highest SAT participation rates in 2018: Colorado Connecticut,Deleware,Michigan,Idaho
# 2. The following states had the highest SAT participation in 2017: Connecticut,Deleware,Michigan,District of Columbia
# 3. Lowest SAT participation in 2018: North Dakota
# 4. Lowest SAT participation in 2017: North Dakota, Mississippi, Iowa
# ________________________________________________________________________________________________________________
#
# 5. Highest ACT participation in 2018: South Carolina, Ohio, Oklahoma, North Carolina, Nevada, Nebraska, Montana, Mississippi, Louisiana, Missouri,Wyoming, Arkansas
# 6. Highest ACT participation in 2017: Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma
# ,North Carolina, Nevada, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Arkansas, Colorado
# 7. Lowest ACT 2018: Maine
# 8. Lowest ACT participation in 2017:Maine

# %%
final.loc[(final["act_2018_composite_score"]==final["act_2018_composite_score"].max())]
# Out:
#          state  sat_2018_participation_rates  \
# 6  Connecticut                         100.0
#
#    sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 6                                 535                  519   1053
#
#    act_2018_participation_rates  act_2018_composite_score  \
# 6                          26.0                      25.6
#
#    act_2017_participation_rates  act_2017_english_score  act_2017_math_score  \
# 6                          31.0                    25.5                 24.6
#
#    act_2017_reading_score  act_2017_science_score  act_2017_composite_score  \
# 6                    25.6                    24.6                      25.2
#
#    sat_2017_participation_rates  sat_2017_reading_and_writing_score  \
# 6                         100.0                                 530
#
#    sat_2017_math_score  sat_2017_total_score
# 6                  512                  1041

# %%
final.loc[(final["act_2018_composite_score"]==final["act_2018_composite_score"].min())]
# Out:
#      state  sat_2018_participation_rates  sat_2018_reading_and_writing_score  \
# 29  Nevada                          23.0                                 574
#
#     sat_2018_math_score  total  act_2018_participation_rates  \
# 29                  566   1140                         100.0
#
#     act_2018_composite_score  act_2017_participation_rates  \
# 29                      17.7                         100.0
#
#     act_2017_english_score  act_2017_math_score  act_2017_reading_score  \
# 29                    16.3                 18.0                    18.1
#
#     act_2017_science_score  act_2017_composite_score  \
# 29                    18.2                      17.8
#
#     sat_2017_participation_rates  sat_2017_reading_and_writing_score  \
# 29                          26.0                                 563
#
#     sat_2017_math_score  sat_2017_total_score
# 29                  553                  1116

# %%
final.loc[(final["act_2017_composite_score"]==final["act_2017_composite_score"].max())]
# Out:
#             state  sat_2018_participation_rates  \
# 30  New Hampshire                          96.0
#
#     sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 30                                 535                  528   1063
#
#     act_2018_participation_rates  act_2018_composite_score  \
# 30                          16.0                      25.1
#
#     act_2017_participation_rates  act_2017_english_score  act_2017_math_score  \
# 30                          18.0                    25.4                 25.1
#
#     act_2017_reading_score  act_2017_science_score  act_2017_composite_score  \
# 30                    26.0                    24.9                      25.5
#
#     sat_2017_participation_rates  sat_2017_reading_and_writing_score  \
# 30                          96.0                                 532
#
#     sat_2017_math_score  sat_2017_total_score
# 30                  520                  1052

# %%
final.loc[(final["act_2017_composite_score"]==final["act_2017_composite_score"].min())]
# Out:
#      state  sat_2018_participation_rates  sat_2018_reading_and_writing_score  \
# 29  Nevada                          23.0                                 574
#
#     sat_2018_math_score  total  act_2018_participation_rates  \
# 29                  566   1140                         100.0
#
#     act_2018_composite_score  act_2017_participation_rates  \
# 29                      17.7                         100.0
#
#     act_2017_english_score  act_2017_math_score  act_2017_reading_score  \
# 29                    16.3                 18.0                    18.1
#
#     act_2017_science_score  act_2017_composite_score  \
# 29                    18.2                      17.8
#
#     sat_2017_participation_rates  sat_2017_reading_and_writing_score  \
# 29                          26.0                                 563
#
#     sat_2017_math_score  sat_2017_total_score
# 29                  553                  1116

# %%
final.loc[(final["sat_2017_total_score"]==final["sat_2017_total_score"].max())]
# Out:
#         state  sat_2018_participation_rates  \
# 24  Minnesota                           4.0
#
#     sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 24                                 643                  655   1298
#
#     act_2018_participation_rates  act_2018_composite_score  \
# 24                          99.0                      21.3
#
#     act_2017_participation_rates  act_2017_english_score  act_2017_math_score  \
# 24                         100.0                    20.4                 21.5
#
#     act_2017_reading_score  act_2017_science_score  act_2017_composite_score  \
# 24                    21.8                    21.6                      21.5
#
#     sat_2017_participation_rates  sat_2017_reading_and_writing_score  \
# 24                           3.0                                 644
#
#     sat_2017_math_score  sat_2017_total_score
# 24                  651                  1295

# %%
final.loc[(final["sat_2017_total_score"]==final["sat_2017_total_score"].min())]
# Out:
#                   state  sat_2018_participation_rates  \
# 8  District of Columbia                          92.0
#
#    sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 8                                 497                  480    977
#
#    act_2018_participation_rates  act_2018_composite_score  \
# 8                          32.0                      23.6
#
#    act_2017_participation_rates  act_2017_english_score  act_2017_math_score  \
# 8                          32.0                    24.4                 23.5
#
#    act_2017_reading_score  act_2017_science_score  act_2017_composite_score  \
# 8                    24.9                    23.5                      24.2
#
#    sat_2017_participation_rates  sat_2017_reading_and_writing_score  \
# 8                         100.0                                 482
#
#    sat_2017_math_score  sat_2017_total_score
# 8                  468                   950

# %%
final.loc[(final["total"]==final["total"].max())]
# Out:
#         state  sat_2018_participation_rates  \
# 24  Minnesota                           4.0
#
#     sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 24                                 643                  655   1298
#
#     act_2018_participation_rates  act_2018_composite_score  \
# 24                          99.0                      21.3
#
#     act_2017_participation_rates  act_2017_english_score  act_2017_math_score  \
# 24                         100.0                    20.4                 21.5
#
#     act_2017_reading_score  act_2017_science_score  act_2017_composite_score  \
# 24                    21.8                    21.6                      21.5
#
#     sat_2017_participation_rates  sat_2017_reading_and_writing_score  \
# 24                           3.0                                 644
#
#     sat_2017_math_score  sat_2017_total_score
# 24                  651                  1295

# %%
final.loc[(final["total"]==final["total"].min())]
# Out:
#                   state  sat_2018_participation_rates  \
# 8  District of Columbia                          92.0
#
#    sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 8                                 497                  480    977
#
#    act_2018_participation_rates  act_2018_composite_score  \
# 8                          32.0                      23.6
#
#    act_2017_participation_rates  act_2017_english_score  act_2017_math_score  \
# 8                          32.0                    24.4                 23.5
#
#    act_2017_reading_score  act_2017_science_score  act_2017_composite_score  \
# 8                    24.9                    23.5                      24.2
#
#    sat_2017_participation_rates  sat_2017_reading_and_writing_score  \
# 8                         100.0                                 482
#
#    sat_2017_math_score  sat_2017_total_score
# 8                  468                   950

# %%
final.columns
# Out:
# Index(['state', 'sat_2018_participation_rates',
#        'sat_2018_reading_and_writing_score', 'sat_2018_math_score', 'total',
#        'act_2018_participation_rates', 'act_2018_composite_score',
#        'act_2017_participation_rates', 'act_2017_english_score',
#        'act_2017_math_score', 'act_2017_reading_score',
#        'act_2017_science_score', 'act_2017_composite_score',
#        'sat_2017_participation_rates', 'sat_2017_reading_and_writing_score',
#        'sat_2017_math_score', 'sat_2017_total_score'],
#       dtype='object')

# %% [markdown]
# Which states have the highest and lowest mean total/composite scores for the:
# 1. Minnesota has the highest composite score for the 2018 SAT (1298) and 2017 SAT (1295)
# 2. DC has the lowest SAT composite score for the 2017 and 2018 SAT at 950 and 977
# 3. Nevada has the lowest ACT composite score for 2018 and 2017 at 17.7 and 17.8
# 4. New Hampshire has the highest ACT 2017 composite score for 2017
# 5. Connecticut has the highest ACT composite score for 2018 at 25.6

# %% [markdown]
# Do any states with 100% participation on a given test have a rate change year-to-year?
# Do any states show have >50% participation on both tests either year?

# %%
final.loc[final["sat_2018_participation_rates"]>70].head(10).sort_values(by="sat_2018_participation_rates", ascending=False)
# Out:
#                    state  sat_2018_participation_rates  \
# 5               Colorado                         100.0
# 6            Connecticut                         100.0
# 7               Delaware                         100.0
# 12                 Idaho                         100.0
# 23              Michigan                         100.0
# 13              Illinois                          99.0
# 19                 Maine                          99.0
# 8   District of Columbia                          92.0
# 22         Massachusetts                          80.0
# 21              Maryland                          76.0
#
#     sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 5                                  519                  506   1025
# 6                                  535                  519   1053
# 7                                  505                  492    998
# 12                                 508                  493   1001
# ...

# %%
sat_df= final["sat_2017_participation_rates"]>70

# %%
locate= final.loc[sat_df,["sat_2017_participation_rates","state"]]
#another example of masking

# %%
locate.sort_values(by="sat_2017_participation_rates", ascending=False)
# Out:
#     sat_2017_participation_rates                 state
# 6                          100.0           Connecticut
# 7                          100.0              Delaware
# 8                          100.0  District of Columbia
# 23                         100.0              Michigan
# 30                          96.0         New Hampshire
# 19                          95.0                 Maine
# 12                          93.0                 Idaho
# 9                           83.0               Florida
# 22                          76.0         Massachusetts
# 40                          71.0          Rhode Island

# %%
sat_df_2018= final["sat_2018_participation_rates"]>70

# %%
locate_2018= final.loc[sat_df,["sat_2018_participation_rates","state"]].sort_values(by="sat_2018_participation_rates", ascending=False)

# %%
locate_2018
# Out:
#     sat_2018_participation_rates                 state
# 6                          100.0           Connecticut
# 7                          100.0              Delaware
# 12                         100.0                 Idaho
# 23                         100.0              Michigan
# 19                          99.0                 Maine
# 40                          97.0          Rhode Island
# 30                          96.0         New Hampshire
# 8                           92.0  District of Columbia
# 22                          80.0         Massachusetts
# 9                           56.0               Florida

# %%
 final.loc[sat_df,"state"]
# Out:
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 12                   Idaho
# 19                   Maine
# 22           Massachusetts
# 23                Michigan
# 30           New Hampshire
# 40            Rhode Island
# Name: state, dtype: object

# %%
#partially taken from https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/barchart.html


labels = final.loc[sat_df,"state"]
SAT_2017 = final.loc[sat_df,"sat_2017_participation_rates"]
SAT_2018 = final.loc[sat_df,"sat_2018_participation_rates"]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(70,30))
rects1 = ax.bar(x - width/2, SAT_2017, width, label='SAT 2017')
rects2 = ax.bar(x + width/2, SAT_2018, width, label='SAT 2018')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Rates')
ax.set_title('Rates by State and Year')
ax.set_xticks(x)
ax.set_xticklabels(labels,size=50)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points", size=50,
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
#We can see here that D.C went from 100% participation rate to 92%

# %%
act_df= final["act_2017_participation_rates"]>70 
final.loc[act_df,"act_2017_participation_rates"]
# Out:
# 0     100.0
# 3     100.0
# 5     100.0
# 9      73.0
# 11     90.0
# 13     93.0
# 16     73.0
# 17    100.0
# 18    100.0
# 24    100.0
# 25    100.0
# 26    100.0
# 27    100.0
# 28     84.0
# 29    100.0
# 34    100.0
# 35     98.0
# 36    100.0
# 37     75.0
# 41    100.0
# 42     80.0
# 43    100.0
# 45    100.0
# 50    100.0
# 51    100.0
# Name: act_2017_participation_rates, dtype: float64

# %%
act_df_2018= final["act_2018_participation_rates"]>70

# %%
final.head()
# Out:
#         state  sat_2018_participation_rates  \
# 0     Alabama                           6.0
# 1      Alaska                          43.0
# 2     Arizona                          29.0
# 3    Arkansas                           5.0
# 4  California                          60.0
#
#    sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 0                                 595                  571   1166
# 1                                 562                  544   1106
# 2                                 577                  572   1149
# 3                                 592                  576   1169
# 4                                 540                  536   1076
#
#    act_2018_participation_rates  act_2018_composite_score  \
# 0                         100.0                      19.1
# 1                          33.0                      20.8
# 2                          66.0                      19.2
# 3                         100.0                      19.4
# ...

# %%
changes_in_rates= final[['state','sat_2017_participation_rates','sat_2018_participation_rates', 'act_2017_participation_rates',
      'act_2018_participation_rates']]

# %%
changes_in_rates.sort_values(by="sat_2017_participation_rates",ascending=False).head(10)
# Out:
#                    state  sat_2017_participation_rates  \
# 8   District of Columbia                         100.0
# 23              Michigan                         100.0
# 6            Connecticut                         100.0
# 7               Delaware                         100.0
# 30         New Hampshire                          96.0
# 19                 Maine                          95.0
# 12                 Idaho                          93.0
# 9                Florida                          83.0
# 22         Massachusetts                          76.0
# 40          Rhode Island                          71.0
#
#     sat_2018_participation_rates  act_2017_participation_rates  \
# 8                           92.0                          32.0
# 23                         100.0                          29.0
# 6                          100.0                          31.0
# 7                          100.0                          18.0
# ...

# %%
changes_in_rates.sort_values(by="sat_2018_participation_rates",ascending=False).head(10)
# Out:
#                    state  sat_2017_participation_rates  \
# 5               Colorado                          11.0
# 6            Connecticut                         100.0
# 7               Delaware                         100.0
# 23              Michigan                         100.0
# 12                 Idaho                          93.0
# 19                 Maine                          95.0
# 13              Illinois                           9.0
# 40          Rhode Island                          71.0
# 30         New Hampshire                          96.0
# 8   District of Columbia                         100.0
#
#     sat_2018_participation_rates  act_2017_participation_rates  \
# 5                          100.0                         100.0
# 6                          100.0                          31.0
# 7                          100.0                          18.0
# 23                         100.0                          29.0
# ...

# %%
changes_in_rates.sort_values(by="act_2018_participation_rates",ascending=False)
# Out:
#                    state  sat_2017_participation_rates  \
# 0                Alabama                           5.0
# 17              Kentucky                           4.0
# 50             Wisconsin                           3.0
# 45                  Utah                           3.0
# 43             Tennessee                           5.0
# 41        South Carolina                          50.0
# 37                  Ohio                          12.0
# 36              Oklahoma                           7.0
# 34        North Carolina                          49.0
# 29                Nevada                          26.0
# 28              Nebraska                           3.0
# 27               Montana                          10.0
# 25           Mississippi                           2.0
# 18             Louisiana                           4.0
# 26              Missouri                           3.0
# 51               Wyoming                           3.0
# ...

# %%
changes_in_rates.sort_values(by="act_2017_participation_rates",ascending=False).head(20)
# Out:
#              state  sat_2017_participation_rates  \
# 0          Alabama                           5.0
# 17        Kentucky                           4.0
# 50       Wisconsin                           3.0
# 45            Utah                           3.0
# 43       Tennessee                           5.0
# 41  South Carolina                          50.0
# 36        Oklahoma                           7.0
# 34  North Carolina                          49.0
# 29          Nevada                          26.0
# 27         Montana                          10.0
# 25     Mississippi                           2.0
# 24       Minnesota                           3.0
# 18       Louisiana                           4.0
# 26        Missouri                           3.0
# 51         Wyoming                           3.0
# 5         Colorado                          11.0
# 3         Arkansas                           3.0
# 35    North Dakota                           2.0
# ...

# %% [markdown]
# SAT
# 1. D.C decreased from 100 to 92 participation rate in the 2018 SAT
# 2. Maine had a slight increase in from 2017 to 2018 in SAT participation rates (from 95% to 99% )
# 3. Idaho had a slight increase from 93% to 100% in SAT participation rates
# 4. Florida has a major decrease from 83% to 56%
# 5. MA had a slight increase from 76% to 80%
# 6. Colorado had a huge increase from 11% to 100%
#
# I'm interested in looking into: Colorado, Illinois (both large increases), and Florida (big decrease).
#
# ACT
# 1. Colorado had a huge decrease from 100% to 30% in ACT participation
# 2. Ohio shows a 15% increase in ACT participation rates
# 3. Alaska went from 65% to 33% participation

# %% [markdown]
# Do any states have >50% participation on both tests either year?

# %%
greater_than_50_sat_both_years = final.loc[(final["sat_2017_participation_rates"]>50) & (final["sat_2018_participation_rates"]>50)&(final["act_2018_participation_rates"]>50) &(final["act_2017_participation_rates"]>50)]

# %%
greater_than_50_sat_both_years
# Out:
#       state  sat_2018_participation_rates  sat_2018_reading_and_writing_score  \
# 9   Florida                          56.0                                 550
# 10  Georgia                          70.0                                 542
# 11   Hawaii                          56.0                                 480
#
#     sat_2018_math_score  total  act_2018_participation_rates  \
# 9                   549   1099                          66.0
# 10                  522   1064                          53.0
# 11                  530   1010                          89.0
#
#     act_2018_composite_score  act_2017_participation_rates  \
# 9                       19.9                          73.0
# 10                      21.4                          55.0
# 11                      18.9                          90.0
#
#     act_2017_english_score  act_2017_math_score  act_2017_reading_score  \
# 9                     19.0                 19.4                    21.0
# ...

# %% [markdown]
# The following states had greater than 50% participation in both tests for both years:
# Florida, Georgia, Hawaii

# %%
greater_than_50_2017=  final.loc[(final["sat_2017_participation_rates"]>50)&(final["act_2017_participation_rates"]>50)]

# %%
greater_than_50_2018= final.loc[(final["sat_2018_participation_rates"]>50)&(final["act_2018_participation_rates"]>50)]

# %%
greater_than_50_2017
# Out:
#       state  sat_2018_participation_rates  sat_2018_reading_and_writing_score  \
# 9   Florida                          56.0                                 550
# 10  Georgia                          70.0                                 542
# 11   Hawaii                          56.0                                 480
#
#     sat_2018_math_score  total  act_2018_participation_rates  \
# 9                   549   1099                          66.0
# 10                  522   1064                          53.0
# 11                  530   1010                          89.0
#
#     act_2018_composite_score  act_2017_participation_rates  \
# 9                       19.9                          73.0
# 10                      21.4                          55.0
# 11                      18.9                          90.0
#
#     act_2017_english_score  act_2017_math_score  act_2017_reading_score  \
# 9                     19.0                 19.4                    21.0
# ...

# %%
greater_than_50_2018
# Out:
#              state  sat_2018_participation_rates  \
# 9          Florida                          56.0
# 10         Georgia                          70.0
# 11          Hawaii                          56.0
# 34  North Carolina                          52.0
# 41  South Carolina                          55.0
#
#     sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 9                                  550                  549   1099
# 10                                 542                  522   1064
# 11                                 480                  530   1010
# 34                                 554                  543   1098
# 41                                 547                  523   1070
#
#     act_2018_participation_rates  act_2018_composite_score  \
# 9                           66.0                      19.9
# 10                          53.0                      21.4
# 11                          89.0                      18.9
# ...

# %%
lower_than_50= final.loc[(final["sat_2018_participation_rates"]<50)&(final["act_2018_participation_rates"]<50)]

# %%
lower_than_50
# Out:
#      state  sat_2018_participation_rates  sat_2018_reading_and_writing_score  \
# 1   Alaska                          43.0                                 562
# 38  Oregon                          48.0                                 564
#
#     sat_2018_math_score  total  act_2018_participation_rates  \
# 1                   544   1106                          33.0
# 38                  553   1117                          42.0
#
#     act_2018_composite_score  act_2017_participation_rates  \
# 1                       20.8                          65.0
# 38                      21.3                          40.0
#
#     act_2017_english_score  act_2017_math_score  act_2017_reading_score  \
# 1                     18.7                 19.8                    20.4
# 38                    21.2                 21.5                    22.4
#
#     act_2017_science_score  act_2017_composite_score  \
# 1                     19.9                      19.8
# ...

# %% [markdown]
# 1. States with over 50% participation in 2017: Florida,Georgia, Hawaii
# 2. States with over 50% participation rate in 2018: Florida,Georgia, Hawaii, North Carolina, South Carolina

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(10,10))

#this code is from one of our lessons
corr = final.corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):
    sns.heatmap(corr, mask=mask, square=True, annot=True, vmin=-1, vmax=1, linewidths=.5)

plt.title("Correlation between 2017 and 2018 ACT and SAT data")
# Out:
# Text(0.5, 1.0, 'Correlation between 2017 and 2018 ACT and SAT data')

# %%
final.head() 
#this is to difficult to interpret/ too much information. Let's narrow our columns down and rerun the heatmap
# Out:
#         state  sat_2018_participation_rates  \
# 0     Alabama                           6.0
# 1      Alaska                          43.0
# 2     Arizona                          29.0
# 3    Arkansas                           5.0
# 4  California                          60.0
#
#    sat_2018_reading_and_writing_score  sat_2018_math_score  total  \
# 0                                 595                  571   1166
# 1                                 562                  544   1106
# 2                                 577                  572   1149
# 3                                 592                  576   1169
# 4                                 540                  536   1076
#
#    act_2018_participation_rates  act_2018_composite_score  \
# 0                         100.0                      19.1
# 1                          33.0                      20.8
# 2                          66.0                      19.2
# 3                         100.0                      19.4
# ...

# %%
final.rename(columns={"total":"sat_2018_total_score"},inplace=True)
# needed to rename this so it is clear this total is for SAT 2018

# %%
narrowed_down_final =final[["state","sat_2018_participation_rates","act_2018_participation_rates","sat_2018_total_score","act_2018_composite_score","sat_2017_participation_rates","act_2017_participation_rates","sat_2017_total_score","act_2017_composite_score"]]

# %%
plt.figure(figsize=(10,10))

#this code is from one of our lessons
corr = narrowed_down_final.corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):
    sns.heatmap(corr, mask=mask, square=True, annot=True, vmin=-1, vmax=1, linewidths=.5)

plt.title("Correlation between 2017 and 2018 ACT and SAT data")
# Out:
# Text(0.5, 1.0, 'Correlation between 2017 and 2018 ACT and SAT data')

# %%
final.head()
# Out:
#         state  sat_2018_participation_rates  \
# 0     Alabama                           6.0
# 1      Alaska                          43.0
# 2     Arizona                          29.0
# 3    Arkansas                           5.0
# 4  California                          60.0
#
#    sat_2018_reading_and_writing_score  sat_2018_math_score  \
# 0                                 595                  571
# 1                                 562                  544
# 2                                 577                  572
# 3                                 592                  576
# 4                                 540                  536
#
#    sat_2018_total_score  act_2018_participation_rates  \
# 0                  1166                         100.0
# 1                  1106                          33.0
# 2                  1149                          66.0
# 3                  1169                         100.0
# 4                  1076                          27.0
#
# ...

# %%
nd= final.loc[(final["state"]=="North Dakota") | (final["state"]=="Mississippi")| (final["state"]=="South Dakota")| (final["state"]=="Nebraska")]

# %%
nd
# Out:
#            state  sat_2018_participation_rates  \
# 25   Mississippi                           3.0
# 28      Nebraska                           3.0
# 35  North Dakota                           2.0
# 42  South Dakota                           3.0
#
#     sat_2018_reading_and_writing_score  sat_2018_math_score  \
# 25                                 630                  606
# 28                                 629                  623
# 35                                 640                  643
# 42                                 622                  618
#
#     sat_2018_total_score  act_2018_participation_rates  \
# 25                  1236                         100.0
# 28                  1252                         100.0
# 35                  1283                          98.0
# 42                  1240                          77.0
#
#     act_2018_composite_score  act_2017_participation_rates  \
# 25                      18.6                         100.0
# ...

# %%
# Set size of figure: eight by five.
plt.figure(figsize=(8, 5))

# Create a bar chart.
# plt.bar() will create a vertical bar chart.
plt.bar(["North Dakota SAT","North Dakota ACT"], # We have to specify our X labels/location.
        [2,98]) # We have to specify the Y height.
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(figsize=(10,20),nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_ylabel("Number of States")
        plt.tight_layout()

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
final.columns[1:]
# Out:
# Index(['sat_2018_participation_rates', 'sat_2018_reading_and_writing_score',
#        'sat_2018_math_score', 'sat_2018_total_score',
#        'act_2018_participation_rates', 'act_2018_composite_score',
#        'act_2017_participation_rates', 'act_2017_english_score',
#        'act_2017_math_score', 'act_2017_reading_score',
#        'act_2017_science_score', 'act_2017_composite_score',
#        'sat_2017_participation_rates', 'sat_2017_reading_and_writing_score',
#        'sat_2017_math_score', 'sat_2017_total_score'],
#       dtype='object')

# %%
list_of_columns_in_data= final.columns[1:]

list_of_titles_in_data= final.columns[1:]

list_of_xlabels_in_data= final.columns[1:]

# %%
subplot_histograms(final, list_of_columns_in_data, list_of_titles_in_data, list_of_xlabels_in_data)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017 -- **I don't believe this makes sense since the scoring is totally different for the SAT and ACT**
# - SAT vs. ACT verbal/reading scores for 2017 -- **I don't believe this makes sense since the scoring is totally different for the SAT and ACT**
# - SAT vs. ACT total/composite scores for 2017 -- **I don't believe this makes sense since the scoring is totally different for the SAT and ACT**
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
#participation vs average score
scatter_data_act= final[["sat_2018_total_score","sat_2018_participation_rates"]]

# %%
plt.scatter(final["sat_2018_total_score"],final["sat_2018_participation_rates"])
plt.title("SAT participation against final score")
plt.ylabel("Participation")
plt.xlabel("Score")
# as participation increases, scores decrease
# Out:
# Text(0.5, 0, 'Score')

# %%
plt.scatter(final["act_2018_composite_score"],final["act_2018_participation_rates"])
plt.title("ACT participation against final score")
plt.ylabel("Participation")
plt.xlabel("Score")
# as participation increases, scores decrease
# Out:
# Text(0.5, 0, 'Score')

# %%
plt.scatter(final["sat_2017_total_score"],final["sat_2018_total_score"])
plt.title("SAT 2017 and 2018 Total Scores ")
plt.ylabel("2017 Total Score")
plt.xlabel("2018 Total Score")
# as participation increases, scores decrease
# Out:
# Text(0.5, 0, '2018 Total Score')

# %%
plt.scatter(final["act_2017_composite_score"],final["act_2018_composite_score"])
plt.title("ACT 2017 and 2018 Total Scores ")
plt.ylabel("2017 Total Score")
plt.xlabel("2018 Total Score")
# as participation increases, scores decrease
# Out:
# Text(0.5, 0, '2018 Total Score')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
sat_participation_data=final[["sat_2017_participation_rates","sat_2018_participation_rates"]]

# %%
# sns.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)
plt.title("SAT Participation Rates 2017 and 2018")
sns.boxplot(data=sat_participation_data)
#slight increase for 2018

# %%
sat__act_participation_data_2017=final[["sat_2017_participation_rates","act_2017_participation_rates"]]

# %%
plt.title("SAT and ACT Participation Rates 2017")
sns.boxplot(data=sat__act_participation_data_2017)

# %% [markdown]
# The overall median participation rate for the ACT is much higher than that of the SAT (40% vs 65%)

# %%
sat__act_participation_data_2018=final[["sat_2018_participation_rates","act_2018_participation_rates"]]

# %%
plt.title("SAT and ACT Participation Rates 2018")
sns.boxplot(data=sat__act_participation_data_2018)

# %%
final["sat_2018_participation_rates"].describe()
# Out:
# count     51.000000
# mean      45.745098
# std       37.314256
# min        2.000000
# 25%        4.500000
# 50%       52.000000
# 75%       77.500000
# max      100.000000
# Name: sat_2018_participation_rates, dtype: float64

# %%
final["act_2018_participation_rates"].describe()
# Out:
# count     51.000000
# mean      61.725490
# std       34.037085
# min        7.000000
# 25%       28.500000
# 50%       66.000000
# 75%      100.000000
# max      100.000000
# Name: act_2018_participation_rates, dtype: float64

# %%
act_participation_data=final[["act_2017_participation_rates","act_2018_participation_rates"]]

# %%
plt.title("ACT Participation Rates 2017 and 2018")
sns.boxplot(data=act_participation_data)

# %%
act_score_data=final[["act_2017_composite_score","act_2018_composite_score"]]

# %%
plt.title("ACT Composite Scores 2017 and 2018")
sns.boxplot(data=act_score_data)

# %%
sat_score_data=final[["sat_2017_total_score","sat_2018_total_score"]]

# %%
plt.title("SAT Total Scores 2017 and 2018")
sns.boxplot(data=sat_score_data)

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
illi= final.loc[final["state"]=="Illinois"]

# %%
illi
# Out:
#        state  sat_2018_participation_rates  \
# 13  Illinois                          99.0
#
#     sat_2018_reading_and_writing_score  sat_2018_math_score  \
# 13                                 513                  506
#
#     sat_2018_total_score  act_2018_participation_rates  \
# 13                  1019                          43.0
#
#     act_2018_composite_score  act_2017_participation_rates  \
# 13                      23.9                          93.0
#
#     act_2017_english_score  act_2017_math_score  act_2017_reading_score  \
# 13                    21.0                 21.2                    21.6
#
#     act_2017_science_score  act_2017_composite_score  \
# 13                    21.3                      21.4
#
#     sat_2017_participation_rates  sat_2017_reading_and_writing_score  \
# 13                           9.0                                 559
#
#     sat_2017_math_score  sat_2017_total_score
# 13                  556                  1115

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
subplot_histograms(final, list_of_columns_in_data, list_of_titles_in_data, list_of_xlabels_in_data)

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: By analyzing the histograms of each category below, it does not look like this data reflects the conclusions of the central limit theorm as there aren't any normally distributed histograms.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math: It seems the math sections look slightly more similar to a normal distribution (better to use kde).
#     - Reading: Reading does not seem to follow this assumption based off of the histograms above.
#     - Rates: Rates do not follow a normal distribution.
#
# Explain your answers for each distribution and how you think this will affect estimates made from these data.
#
# It will be hard to estimate the confidence interval confidently knowing that none of these distributions follow a normal distribution.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: It doesn't since the data doesn't follow the central limit theorm

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: No, because the scores also do not follow the central limit theorm

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Some interesting readings I found:
#     1. Originally, I chose to focus on Colorado, Illinois, and Florida. Colorado and Illinois had huge increases in SAT participation, whereas Florida had a huge decrease. I discovered that there are many states that have decided to require either the ACT or the SAT in recent years, this is strongly reflected in the data: https://blog.prepscholar.com/which-states-require-the-sat and https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
#
#     Turns out Colorado started requiring the SAT. Illinois was a bit trickier to explain, however in 2018 the state announced that they would provide free tuition for lower income students. This may have led more students into taking college admissions tests: https://www.educationdive.com/news/free-tuition-approved-for-lower-income-u-of-illinois-in-state-students/531159/
#
#     3. How students decide to take the test: this article shows that students usually decide to take the exam based on how well they feel they will do on it. https://www.usnews.com/education/best-colleges/articles/act-vs-sat-how-to-decide-which-test-to-take
#
# So what happened in Florida?
#
# After further investigation, it looks like Florida's participation rate for 2018 is incorrect in the data!!! In the collegeboard report, it lists Floridas participation as 97% in the 2018 SAT.

# %%
fl= final.loc[final["state"]=="Florida"]

# %%
fl[["state","sat_2017_participation_rates","sat_2018_participation_rates","act_2017_participation_rates","act_2018_participation_rates"]]
# Out:
#      state  sat_2017_participation_rates  sat_2018_participation_rates  \
# 9  Florida                          83.0                          56.0
#
#    act_2017_participation_rates  act_2018_participation_rates
# 9                          73.0                          66.0

# %%
oregon= final.loc[final["state"]=="Oregon"]

# %%
oregon[["state","sat_2017_participation_rates","sat_2018_participation_rates","act_2017_participation_rates","act_2018_participation_rates"]]
# Out:
#      state  sat_2017_participation_rates  sat_2018_participation_rates  \
# 38  Oregon                          43.0                          48.0
#
#     act_2017_participation_rates  act_2018_participation_rates
# 38                          40.0                          42.0

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Refer to presentation as to why Oregon has been picked.
#
# Market Research: What drives states to require college admission exams? What makes states decide one exam over the other?  What is the current state of education in X state?
# Marketing:  To increase student confidence in exam: offer webinars and free online resources via social media platforms for targeted audience
# Discounted price for the exam: Test whether or not this increases participation
